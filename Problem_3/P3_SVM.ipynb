# %% [markdown]
# # Problem 3: TensorFlow and Edge Detection using SVM

# %%
# %matplotlib inline
from __future__ import division
from ipywidgets import interact
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import shutil
from utils import *
from HOG import *

# %% [markdown]
# Your task is to construct a SVM using the tf.estimator framework.
# We have written most of the tf.estimator framework and generated the data. Your task is to fill in the feature extractor section and the **``` model_fn ``` ** function below. Please read through the Tensorflow Example IPython Notebook first.

# %% [markdown]
# First, we generate the data.

# %%
# Cell [a]
# generating data!
x_train, y_train = generate_data(N=5000)
x_eval, y_eval = generate_data(N=1000)
x_pred, y_true = generate_data(N=1000)
c = ['powderblue' if lb == 1 else 'indianred' for lb in y_train]
plt.scatter(x_train[:,0], x_train[:,1], c = c, alpha=0.5, s=50)

# %% [markdown]
# ### Edit in Part (iv), but still run for Part(iii)

# %%
# Cell [b]
# Here, you need to define your features. You should use numpy operations.
# Feature extractor
def identityFeatureExtractor(x):
    return x
def customFeatureExtractor(x):
    # You need to write a feature extractor
    # It takes in x, a N x 2 array and outputs features of your design.
    # It should output a N x M array where M is the number of features
    # For example, it can output x1, x2, x1*x2
    ### Your code starts here ###
    #phi_x = ...
    #############################
    return phi_x

########## TO DO #######################
# Select which feature extractor you want
featureExtractor = identityFeatureExtractor
# featureExtractor = customFeatureExtractor

# %% [markdown]
# We start building the Estimator framework.
# Make sure you define lambda here

# %%
# Cell [c]
## Settings for the estimator
# location to save model information
model_dir = "training_checkpoints"
rc = tf.estimator.RunConfig().replace(model_dir=model_dir,
                                      tf_random_seed=None,
                                      save_summary_steps=100,
                                      save_checkpoints_steps=1000,
                                      keep_checkpoint_max=1000,
                                      log_step_count_steps=1000)

# hyperparameters, batch sizes, learning rate
hps = tf.contrib.training.HParams(
    train_batch_size = 32,
    eval_batch_size = 32,
    ############ Select your learning rate and lambda value here ############
    lr =  0.05,
    lam = 0.5
    #########################################################################
    )

# %% [markdown]
# ### Part (iii)
# ```model_fn``` is defined here. Your task is to fill in the missing code

# %%
# Cell [d]
# Defining necessary functions for the estimator 
# input data functions for train, evalulation and prediction
# note that x and y are fed in as dictionaries
train_input_function = tf.estimator.inputs.numpy_input_fn(x={"x":featureExtractor(x_train)},
                                                          y={"y":y_train},
                                                          batch_size=hps.train_batch_size,
                                                          num_epochs=None,
                                                          shuffle=True)
eval_input_function = tf.estimator.inputs.numpy_input_fn(x={"x":featureExtractor(x_eval)},
                                                         y={"y":y_eval},
                                                         batch_size=hps.eval_batch_size,
                                                         num_epochs=1,
                                                         shuffle=False)
def predict_input_function(x_dict):
    return tf.estimator.inputs.numpy_input_fn(x=x_dict,
                                              num_epochs=1,
                                              shuffle=False)


def model_fn(features, labels, mode, params):
    predictions = None
    loss = None
    train_op = None
    eval_metric_ops = None 
    export_outputs = None

    x = tf.to_float(features["x"])
    if mode == tf.estimator.ModeKeys.TRAIN or mode == tf.estimator.ModeKeys.EVAL:
        y = tf.to_float(labels["y"])
        with tf.variable_scope("svm"):
            W = tf.get_variable("weights", dtype=tf.float32, shape=(x.shape[-1],1))
            b = tf.get_variable("bias", dtype=tf.float32, shape=(1,))
            ### Your code starts here ###
            # You may find the following functions useful: tf.matmul, tf.reduce_mean, tf.maximum, tf.square, tf.nn.l2_loss, tf.reduce_sum
            # use the ?<function name> functionality in jupyter to find out more about the functions.
            # This should take about 2 lines.
            ###########################
            y_est = tf.matmul(x, W) - b
            loss = tf.reduce_mean(tf.maximum(0.0 , 1-y*y_est)) + params.lam*tf.norm(W)**2   # tf.multiply(params.lam *(tf.norm(W))**2))
            #####
            accuracy = tf.reduce_mean(tf.to_float(y*y_est > 0))
            eval_metric_ops = {"accuracy": tf.metrics.mean(accuracy)}
            if mode == tf.estimator.ModeKeys.TRAIN:
                opt = tf.train.GradientDescentOptimizer(learning_rate=params.lr)
                train_op = opt.minimize(loss, tf.train.get_global_step())
    elif mode == tf.estimator.ModeKeys.PREDICT:
        predictions = {}
        with tf.variable_scope("svm"):
            W = tf.get_variable("weights", shape=(x.shape[-1],1), dtype=tf.float32)
            b = tf.get_variable("bias", shape=(1,), dtype=tf.float32)
            ### Your code starts here ###
            # This should take about 1 line
            #############################
            y_est = tf.matmul(x, W) - b
            #####
            predictions["y_est"] = y_est
            predictions["labels"] = 2*tf.sign(y_est) - 1
    return tf.estimator.EstimatorSpec(mode, 
                                      predictions=predictions, 
                                      loss=loss,
                                      train_op=train_op,
                                      eval_metric_ops=eval_metric_ops)

# %%
# Cell [e]
# Define the estimator object
estimator_model = tf.estimator.Estimator(model_fn, 
                                         params=hps, 
                                         config=rc,
                                         model_dir=model_dir,
                                         )
# Out:
# INFO:tensorflow:Using config: {'_save_checkpoints_secs': None, '_session_config': None, '_keep_checkpoint_max': 1000, '_task_type': 'worker', '_is_chief': True, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fb3a967a210>, '_save_checkpoints_steps': 1000, '_keep_checkpoint_every_n_hours': 10000, '_service': None, '_num_ps_replicas': 0, '_tf_random_seed': None, '_master': '', '_num_worker_replicas': 1, '_task_id': 0, '_log_step_count_steps': 1000, '_model_dir': 'training_checkpoints', '_save_summary_steps': 100}

# %%
# Cell [f]
# Define the specifications for training and evaluation
train_spec = tf.estimator.TrainSpec(input_fn=train_input_function, max_steps=10000)
eval_spec = tf.estimator.EvalSpec(input_fn=eval_input_function, steps=100, start_delay_secs=0)

# %%
# Cell [g]
# Clear graph and start training and evaluating the model
shutil.rmtree(model_dir, ignore_errors=True)
tf.estimator.train_and_evaluate(estimator_model, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 600 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into training_checkpoints/model.ckpt.
# INFO:tensorflow:loss = 1.9840685, step = 1
# INFO:tensorflow:loss = 0.8630638, step = 101 (0.244 sec)
# INFO:tensorflow:loss = 0.8974515, step = 201 (0.177 sec)
# INFO:tensorflow:loss = 0.9666508, step = 301 (0.252 sec)
# INFO:tensorflow:loss = 0.75430506, step = 401 (0.170 sec)
# INFO:tensorflow:loss = 0.90765935, step = 501 (0.166 sec)
# INFO:tensorflow:loss = 0.97318655, step = 601 (0.261 sec)
# INFO:tensorflow:loss = 0.96809065, step = 701 (0.181 sec)
# INFO:tensorflow:loss = 0.8149874, step = 801 (0.171 sec)
# INFO:tensorflow:loss = 1.0101098, step = 901 (0.166 sec)
# INFO:tensorflow:Saving checkpoints for 1001 into training_checkpoints/model.ckpt.
# INFO:tensorflow:global_step/sec: 481.364
# INFO:tensorflow:loss = 0.9639873, step = 1001 (0.300 sec)
# INFO:tensorflow:loss = 0.80666184, step = 1101 (0.235 sec)
# INFO:tensorflow:loss = 0.9369811, step = 1201 (0.242 sec)
# INFO:tensorflow:loss = 0.72421944, step = 1301 (0.348 sec)
# INFO:tensorflow:loss = 0.88896406, step = 1401 (0.246 sec)
# INFO:tensorflow:loss = 0.83710694, step = 1501 (0.256 sec)
# INFO:tensorflow:loss = 0.9140309, step = 1601 (0.164 sec)
# INFO:tensorflow:loss = 0.87860966, step = 1701 (0.168 sec)
# INFO:tensorflow:loss = 0.97873217, step = 1801 (0.511 sec)
# INFO:tensorflow:loss = 0.9298496, step = 1901 (0.268 sec)
# INFO:tensorflow:Saving checkpoints for 2001 into training_checkpoints/model.ckpt.
# INFO:tensorflow:global_step/sec: 344.886
# INFO:tensorflow:loss = 0.9399631, step = 2001 (0.455 sec)
# INFO:tensorflow:loss = 0.97934675, step = 2101 (0.290 sec)
# INFO:tensorflow:loss = 0.8874323, step = 2201 (0.309 sec)
# INFO:tensorflow:loss = 0.9072345, step = 2301 (0.284 sec)
# INFO:tensorflow:loss = 0.9284747, step = 2401 (0.379 sec)
# INFO:tensorflow:loss = 1.1355547, step = 2501 (0.223 sec)
# INFO:tensorflow:loss = 0.9569932, step = 2601 (0.328 sec)
# INFO:tensorflow:loss = 1.0260949, step = 2701 (0.220 sec)
# INFO:tensorflow:loss = 0.8992083, step = 2801 (0.256 sec)
# INFO:tensorflow:loss = 0.93238485, step = 2901 (0.331 sec)
# INFO:tensorflow:Saving checkpoints for 3001 into training_checkpoints/model.ckpt.
# INFO:tensorflow:global_step/sec: 330.477
# INFO:tensorflow:loss = 0.994604, step = 3001 (0.406 sec)
# INFO:tensorflow:loss = 0.7797015, step = 3101 (0.324 sec)
# INFO:tensorflow:loss = 0.8870403, step = 3201 (0.295 sec)
# INFO:tensorflow:loss = 0.8974777, step = 3301 (0.308 sec)
# INFO:tensorflow:loss = 0.9356868, step = 3401 (0.421 sec)
# INFO:tensorflow:loss = 0.915649, step = 3501 (0.348 sec)
# INFO:tensorflow:loss = 0.9943746, step = 3601 (0.313 sec)
# INFO:tensorflow:loss = 0.92939126, step = 3701 (0.299 sec)
# INFO:tensorflow:loss = 0.8938867, step = 3801 (0.260 sec)
# INFO:tensorflow:loss = 0.776758, step = 3901 (0.190 sec)
# INFO:tensorflow:Saving checkpoints for 4001 into training_checkpoints/model.ckpt.
# INFO:tensorflow:global_step/sec: 317.735
# INFO:tensorflow:loss = 0.80285585, step = 4001 (0.390 sec)
# INFO:tensorflow:loss = 0.8487694, step = 4101 (0.189 sec)
# INFO:tensorflow:loss = 0.89188284, step = 4201 (0.284 sec)
# INFO:tensorflow:loss = 0.91569054, step = 4301 (0.205 sec)
# INFO:tensorflow:loss = 0.8221702, step = 4401 (0.281 sec)
# INFO:tensorflow:loss = 1.0664947, step = 4501 (0.396 sec)
# INFO:tensorflow:loss = 0.9499529, step = 4601 (0.272 sec)
# INFO:tensorflow:loss = 0.9427477, step = 4701 (0.378 sec)
# INFO:tensorflow:loss = 0.931453, step = 4801 (0.331 sec)
# INFO:tensorflow:loss = 0.7636495, step = 4901 (0.335 sec)
# INFO:tensorflow:Saving checkpoints for 5001 into training_checkpoints/model.ckpt.
# INFO:tensorflow:global_step/sec: 328.037
# INFO:tensorflow:loss = 0.8673331, step = 5001 (0.381 sec)
# INFO:tensorflow:loss = 1.0154061, step = 5101 (0.292 sec)
# INFO:tensorflow:loss = 1.0078974, step = 5201 (0.283 sec)
# INFO:tensorflow:loss = 0.90667, step = 5301 (0.287 sec)
# INFO:tensorflow:loss = 1.0549186, step = 5401 (0.329 sec)
# INFO:tensorflow:loss = 0.77205735, step = 5501 (0.122 sec)
# INFO:tensorflow:loss = 0.94683945, step = 5601 (0.170 sec)
# INFO:tensorflow:loss = 0.844696, step = 5701 (0.273 sec)
# INFO:tensorflow:loss = 0.7672697, step = 5801 (0.312 sec)
# INFO:tensorflow:loss = 0.9811333, step = 5901 (0.305 sec)
# INFO:tensorflow:Saving checkpoints for 6001 into training_checkpoints/model.ckpt.
# INFO:tensorflow:global_step/sec: 361.969
# INFO:tensorflow:loss = 0.988919, step = 6001 (0.390 sec)
# INFO:tensorflow:loss = 0.93330693, step = 6101 (0.262 sec)
# INFO:tensorflow:loss = 1.0023812, step = 6201 (0.247 sec)
# INFO:tensorflow:loss = 0.89170814, step = 6301 (0.267 sec)
# INFO:tensorflow:loss = 0.7652637, step = 6401 (0.275 sec)
# INFO:tensorflow:loss = 1.0230805, step = 6501 (0.355 sec)
# INFO:tensorflow:loss = 0.8270522, step = 6601 (0.297 sec)
# INFO:tensorflow:loss = 0.82292616, step = 6701 (0.266 sec)
# INFO:tensorflow:loss = 0.8275587, step = 6801 (0.309 sec)
# INFO:tensorflow:loss = 0.9860707, step = 6901 (0.322 sec)
# INFO:tensorflow:Saving checkpoints for 7001 into training_checkpoints/model.ckpt.
# INFO:tensorflow:global_step/sec: 339.894
# INFO:tensorflow:loss = 0.9552699, step = 7001 (0.340 sec)
# INFO:tensorflow:loss = 1.054422, step = 7101 (0.104 sec)
# INFO:tensorflow:loss = 0.9703559, step = 7201 (0.135 sec)
# INFO:tensorflow:loss = 0.89859295, step = 7301 (0.167 sec)
# INFO:tensorflow:loss = 0.96534216, step = 7401 (0.122 sec)
# INFO:tensorflow:loss = 0.9099543, step = 7501 (0.306 sec)
# INFO:tensorflow:loss = 0.8607891, step = 7601 (0.288 sec)
# INFO:tensorflow:loss = 1.0543483, step = 7701 (0.393 sec)
# INFO:tensorflow:loss = 0.71456313, step = 7801 (0.322 sec)
# INFO:tensorflow:loss = 0.8683035, step = 7901 (0.322 sec)
# INFO:tensorflow:Saving checkpoints for 8001 into training_checkpoints/model.ckpt.
# INFO:tensorflow:global_step/sec: 410.683
# INFO:tensorflow:loss = 0.9212655, step = 8001 (0.283 sec)
# INFO:tensorflow:loss = 0.82252914, step = 8101 (0.264 sec)
# INFO:tensorflow:loss = 0.8397844, step = 8201 (0.169 sec)
# INFO:tensorflow:loss = 0.8869442, step = 8301 (0.233 sec)
# INFO:tensorflow:loss = 0.9916688, step = 8401 (0.275 sec)
# INFO:tensorflow:loss = 0.97046894, step = 8501 (0.355 sec)
# INFO:tensorflow:loss = 0.8919809, step = 8601 (0.279 sec)
# INFO:tensorflow:loss = 0.80435437, step = 8701 (0.299 sec)
# INFO:tensorflow:loss = 0.98029596, step = 8801 (0.261 sec)
# INFO:tensorflow:loss = 1.0577791, step = 8901 (0.297 sec)
# INFO:tensorflow:Saving checkpoints for 9001 into training_checkpoints/model.ckpt.
# INFO:tensorflow:global_step/sec: 357.94
# INFO:tensorflow:loss = 1.1207825, step = 9001 (0.355 sec)
# INFO:tensorflow:loss = 1.001913, step = 9101 (0.274 sec)
# INFO:tensorflow:loss = 1.071378, step = 9201 (0.280 sec)
# INFO:tensorflow:loss = 0.8168269, step = 9301 (0.247 sec)
# INFO:tensorflow:loss = 1.0234876, step = 9401 (0.270 sec)
# INFO:tensorflow:loss = 0.97770625, step = 9501 (0.334 sec)
# INFO:tensorflow:loss = 1.036451, step = 9601 (0.261 sec)
# INFO:tensorflow:loss = 0.8751212, step = 9701 (0.301 sec)
# INFO:tensorflow:loss = 0.9872161, step = 9801 (0.302 sec)
# INFO:tensorflow:loss = 0.8989598, step = 9901 (0.346 sec)
# INFO:tensorflow:Saving checkpoints for 10000 into training_checkpoints/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.89445555.
# INFO:tensorflow:Starting evaluation at 2018-02-17-00:48:11
# INFO:tensorflow:Restoring parameters from training_checkpoints/model.ckpt-10000
# INFO:tensorflow:Evaluation [10/100]
# INFO:tensorflow:Evaluation [20/100]
# INFO:tensorflow:Evaluation [30/100]
# INFO:tensorflow:Finished evaluation at 2018-02-17-00:48:11
# INFO:tensorflow:Saving dict for global step 10000: accuracy = 0.43164062, global_step = 10000, loss = 0.9281371

# %%
# Cell [g]
# Make predictions given new x data
y_predict = estimator_model.predict(predict_input_function({"x":featureExtractor(x_pred)}), predict_keys = "y_est")
y_pred = [y["y_est"][0] for y in y_predict]
labels_pred = np.sign(np.array(y_pred))
# Out:
# INFO:tensorflow:Restoring parameters from training_checkpoints/model.ckpt-10000

# %%
# Cell[i]
# Plot predictions
c = ['powderblue' if lb == 1 else 'indianred' for lb in labels_pred]
plt.scatter(x_pred[:,0], x_pred[:,1], c=c, s=50, alpha=0.5)
# misclassified data
d = labels_pred - y_true[:,0]
misclass_idx = np.where(d!= 0)[0]
c = ['red' if lb == 2 else 'blue' for lb in d[misclass_idx]]
plt.scatter(x_pred[misclass_idx,0], x_pred[misclass_idx,1], c=c, s=50, alpha=0.8)

# %%
len(misclass_idx)
# Out:
# 563

# %% [markdown]
# ### Part (vii) SVM with Histograms of Gradients

# %%
# Cell [j]
sess = tf.InteractiveSession()
datasets = np.load('pedestrian_dataset.npz')    # extracted from the original Dalal and Triggs paper dataset available here: http://pascal.inrialpes.fr/data/human/
datasets.keys()

# %%
# Cell [k]
### EXPLORE THE DATASET!
data = datasets['train_pos']
# data = datasets['train_neg']
@interact(k = (0, data.shape[0]-1))
def view_img(k):
    plt.imshow(data[k])

# %%
# Cell[l]
### VISUALIZE HOGs!
data = datasets['train_pos']
# data = datasets['train_neg']

@interact(k = (0, data.shape[0]-1))
def view_img(k):
    plt.figure(figsize = (15,15))    # feel free to change this depending on your screen resolution
    plt.imshow(data[k])
    # we can call .eval() instead of sess.run() below since we're using an InteractiveSession
    plot_cell_hogs(tf_histogram_of_oriented_gradients(data[k])[0].eval())

# %%
# Cell [m]
### USE TENSORFLOW AS A COMPUTATION FRAMEWORK (NOT JUST FOR BACKPROPAGATION!)
##### You code starts here #####
############################################################
# x_train =     # should be of size [#datapoints, 1152] 
# x_eval = 
# x_pred = 
# y_train =     # should be of size [#datapoints, 1]
# y_eval = 
# y_true = 
############################################################
featureExtractor = identityFeatureExtractor

# %%
### RERUN TRAINING CELLS [c]-[g] ABOVE

# %%
# Cell [n]
### VISUALIZE WEIGHTED HOGs!
data = datasets['train_pos']
# data = datasets['train_neg']

weights = np.reshape(estimator_model.get_variable_value('svm/weights'), [1, -1])
pos_weights = np.maximum(weights, 0)
neg_weights = -np.minimum(weights, 0)
@interact(k = (0, data.shape[0]-1), show_image = (False, True))
def view_img(k, show_image):
    plt.figure(figsize = (15,15))    # feel free to change this depending on your screen resolution
    plt.imshow(data[k])
    hog = hog_descriptor(data[k]).eval()
    unweighted_block_hogs = np.mean(hog.reshape([16, 8, 1, 9]), axis=2)
    pos_weighted_block_hogs = np.mean(pos_weights.reshape([16, 8, 1, 9])*hog.reshape([16, 8, 1, 9]), axis=2)
    neg_weighted_block_hogs = np.mean(neg_weights.reshape([16, 8, 1, 9])*hog.reshape([16, 8, 1, 9]), axis=2)

    plt.subplot(1,3,1)
    color = 'yellow' if show_image else 'white'
    plt.imshow(show_image*data[k])
    plot_cell_hogs(unweighted_block_hogs, pixels_in_cell=8, color=color)
    plt.subplot(1,3,2)
    plt.imshow(show_image*data[k])
    plot_cell_hogs(pos_weighted_block_hogs, pixels_in_cell=8, color=color)
    plt.subplot(1,3,3)
    plt.imshow(show_image*data[k])
    plot_cell_hogs(neg_weighted_block_hogs, pixels_in_cell=8, color=color)
